# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
# for dirname, _, filenames in os.walk('/Untitled Folder'):
#     for filename in filenames:
#         print(os.path.join(dirname, filename))

# %%
train=pd.read_csv("Train.csv")
train=train.drop(['Education_Level'], axis=1)
train=train.drop(['VAR1'], axis=1)
train=train.drop(['VAR2'], axis=1)
train=train.drop(['VAR3'], axis=1)
train=train.drop(['VAR4'], axis=1)
train=train.drop(['VAR5'], axis=1)
train=train.drop(['VAR6'], axis=1)
train=train.drop(['VAR7'], axis=1)
train
# Out:
#      Employee_ID Gender   Age Relationship_Status     Hometown  \
# 0      EID_23371      F  42.0             Married     Franklin
# 1      EID_18000      M  24.0              Single  Springfield
# 2       EID_3891      F  58.0             Married      Clinton
# 3      EID_17492      F  26.0              Single      Lebanon
# 4      EID_22534      F  31.0             Married  Springfield
# ...          ...    ...   ...                 ...          ...
# 6995   EID_16328      F  23.0             Married     Franklin
# 6996    EID_8387      F  44.0             Married      Lebanon
# 6997    EID_8077      F  49.0              Single  Springfield
# 6998   EID_19597      F  47.0             Married   Washington
# 6999    EID_1640      F  58.0             Married     Franklin
#
#                            Unit Decision_skill_possess  Time_of_service  \
# 0                            IT             Conceptual              4.0
# ...

# %%
train.columns
# Out:
# Index(['Employee_ID', 'Gender', 'Age', 'Relationship_Status', 'Hometown',
#        'Unit', 'Decision_skill_possess', 'Time_of_service',
#        'Time_since_promotion', 'growth_rate', 'Travel_Rate', 'Post_Level',
#        'Pay_Scale', 'Compensation_and_Benefits', 'Work_Life_balance',
#        'Attrition_rate'],
#       dtype='object')

# %%
train["Hometown"].unique()
# Out:
# array(['Franklin', 'Springfield', 'Clinton', 'Lebanon', 'Washington'],
#       dtype=object)

# %%
train.count()
# Out:
# Employee_ID                  7000
# Gender                       7000
# Age                          6588
# Relationship_Status          7000
# Hometown                     7000
# Unit                         7000
# Decision_skill_possess       7000
# Time_of_service              6856
# Time_since_promotion         7000
# growth_rate                  7000
# Travel_Rate                  7000
# Post_Level                   7000
# Pay_Scale                    6991
# Compensation_and_Benefits    7000
# Work_Life_balance            6989
# Attrition_rate               7000
# dtype: int64

# %%
test=pd.read_csv("Test.csv")
test=test.drop(['Education_Level'], axis=1)
test=test.drop(['VAR1'], axis=1)
test=test.drop(['VAR2'], axis=1)
test=test.drop(['VAR3'], axis=1)
test=test.drop(['VAR4'], axis=1)
test=test.drop(['VAR5'], axis=1)
test=test.drop(['VAR6'], axis=1)
test=test.drop(['VAR7'], axis=1)
test
# Out:
#      Employee_ID Gender   Age Relationship_Status     Hometown       Unit  \
# 0      EID_22713      F  32.0              Single  Springfield        R&D
# 1       EID_9658      M  65.0              Single      Lebanon         IT
# 2      EID_22203      M  52.0             Married  Springfield      Sales
# 3       EID_7652      M  50.0              Single   Washington  Marketing
# 4       EID_6516      F  44.0             Married     Franklin        R&D
# ...          ...    ...   ...                 ...          ...        ...
# 2995   EID_22547      F  32.0              Single     Franklin      Sales
# 2996   EID_10066      F   NaN              Single     Franklin  Marketing
# 2997    EID_7126      F  60.0              Single      Lebanon  Logistics
# 2998    EID_4929      F  51.0             Married  Springfield         IT
# 2999   EID_24750      F  45.0              Single     Franklin      Sales
#
#      Decision_skill_possess  Time_of_service  Time_since_promotion  \
# ...

# %%
test["Unit"].unique()
# Out:
# array(['R&D', 'IT', 'Sales', 'Marketing', 'Purchasing', 'Operarions',
#        'Human Resource Management', 'Logistics', 'Accounting and Finance',
#        'Security', 'Quality', 'Production'], dtype=object)

# %%
test.columns
# Out:
# Index(['Employee_ID', 'Gender', 'Age', 'Relationship_Status', 'Hometown',
#        'Unit', 'Decision_skill_possess', 'Time_of_service',
#        'Time_since_promotion', 'growth_rate', 'Travel_Rate', 'Post_Level',
#        'Pay_Scale', 'Compensation_and_Benefits', 'Work_Life_balance'],
#       dtype='object')

# %%
test.count()
# Out:
# Employee_ID                  3000
# Gender                       3000
# Age                          2839
# Relationship_Status          3000
# Hometown                     3000
# Unit                         3000
# Decision_skill_possess       3000
# Time_of_service              2948
# Time_since_promotion         3000
# growth_rate                  3000
# Travel_Rate                  3000
# Post_Level                   3000
# Pay_Scale                    2997
# Compensation_and_Benefits    3000
# Work_Life_balance            2995
# dtype: int64

# %%
import matplotlib.pyplot as plt

def bar_plot(variable):
    
    """
        input: variable 
        output: bar plot & value count
    """
    #get future
    var= train[variable]
    #count number of categorical variable(value/sample)
    varValue=var.value_counts()
    
    #visualize
    
    plt.figure(figsize=(10,4))
    plt.bar(varValue.index,varValue)
    plt.xticks(varValue.index, varValue.index.values)
    plt.ylabel("Frequency")
    plt.title(variable)
    plt.show()
    
    print("{}: \n {}".format(variable,varValue))

# %%
category1= ["Gender","Age","Education_Level","Relationship_Status","home_town","Unit","Time_of_service","Time_since_promotion","Travel_Rate","Work_Life_balance"]

for c in category1:
    bar_plot(c)
# Out:
# Gender:
#  F    4114
# M    2886
# Name: Gender, dtype: int64
# Age:
#  22.0    235
# 25.0    235
# 27.0    231
# 31.0    218
# 54.0    212
# 60.0    211
# 26.0    210
# 37.0    208
# 35.0    205
# 52.0    199
# 28.0    194
# 42.0    193
# 47.0    193
# 30.0    191
# 32.0    189
# 24.0    185
# 45.0    184
# 21.0    171
# 65.0    152
# 19.0    151
# 23.0    148
# 59.0    136
# 58.0    122
# 20.0    122
# 29.0    115
# 36.0    106
# 33.0    104
# 51.0    103
# 50.0    101
# 34.0     99
# 46.0     98
# 49.0     97
# 64.0     95
# 55.0     94
# 56.0     94
# 43.0     93
# 41.0     92
# 57.0     92
# 38.0     89
# 53.0     88
# 44.0     85
# 39.0     83
# 40.0     81
# 48.0     79
# 63.0     73
# 62.0     69
# 61.0     63
# Name: Age, dtype: int64
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ...

# %%
def plot_hist(variable):
    plt.figure(figsize=(9,3))
    plt.hist(train[variable],bins=50)
    
    plt.xlabel(variable)
    plt.ylabel("Frequency")
    plt.title("{} distribution with hist".format(variable))
    plt.show()

# %%
numericVar =["Age"]

for n in numericVar:
    plot_hist(n)

# %%
print(train['Age'])
# Out:
# 0       42.0
# 1       24.0
# 2       58.0
# 3       26.0
# 4       31.0
#         ...
# 6995    23.0
# 6996    44.0
# 6997    49.0
# 6998    47.0
# 6999    58.0
# Name: Age, Length: 7000, dtype: float64

# %%
train['Relationship_Status'].unique()
# Out:
# array(['Married', 'Single'], dtype=object)

# %%
train['Unit'].unique()
# Out:
# array(['IT', 'Logistics', 'Quality', 'Human Resource Management',
#        'Purchasing', 'Sales', 'Production', 'Operarions',
#        'Accounting and Finance', 'Marketing', 'R&D', 'Security'],
#       dtype=object)

# %%
train['Decision_skill_possess'].unique()
# Out:
# array(['Conceptual', 'Analytical', 'Behavioral', 'Directive'],
#       dtype=object)

# %%
train['Compensation_and_Benefits'].unique()
# Out:
# array(['type2', 'type3', 'type0', 'type4', 'type1'], dtype=object)

# %%
train[["Hometown","Attrition_rate"]].groupby(["Hometown"], as_index=False).mean().sort_values(by="Attrition_rate",ascending=False)
# Out:
#       Hometown  Attrition_rate
# 3  Springfield        0.194084
# 4   Washington        0.188895
# 0      Clinton        0.188464
# 1     Franklin        0.187901
# 2      Lebanon        0.187019

# %%
train[["Time_since_promotion","Attrition_rate"]].groupby(["Time_since_promotion"], as_index=False).mean().sort_values(by="Attrition_rate",ascending=False)
# Out:
#    Time_since_promotion  Attrition_rate
# 4                     4        0.195506
# 2                     2        0.192896
# 0                     0        0.188687
# 3                     3        0.185435
# 1                     1        0.184551

# %%
train["Pay_Scale"]=train["Pay_Scale"].fillna(train["Pay_Scale"].median())

# %%
train['Relationship_Status'].unique()
# Out:
# array(['Married', 'Single'], dtype=object)

# %%
train["Relationship_Status"]=[1 if i =="Married" else 0 for i in train["Relationship_Status"]]

# %%
train['Hometown'].unique()
# Out:
# array(['Franklin', 'Springfield', 'Clinton', 'Lebanon', 'Washington'],
#       dtype=object)

# %%
train.isnull().sum()
# Out:
# Employee_ID                    0
# Gender                         0
# Age                          412
# Relationship_Status            0
# Hometown                       0
# Unit                           0
# Decision_skill_possess         0
# Time_of_service              144
# Time_since_promotion           0
# growth_rate                    0
# Travel_Rate                    0
# Post_Level                     0
# Pay_Scale                      0
# Compensation_and_Benefits      0
# Work_Life_balance             11
# Attrition_rate                 0
# dtype: int64

# %%
train["Pay_Scale"]=train["Pay_Scale"].fillna(train['Pay_Scale'].median())

# %%
train.isnull().sum()
# Out:
# Employee_ID                    0
# Gender                         0
# Age                          412
# Relationship_Status            0
# Hometown                       0
# Unit                           0
# Decision_skill_possess         0
# Time_of_service              144
# Time_since_promotion           0
# growth_rate                    0
# Travel_Rate                    0
# Post_Level                     0
# Pay_Scale                      0
# Compensation_and_Benefits      0
# Work_Life_balance             11
# Attrition_rate                 0
# dtype: int64

# %%
train[train["Age"].isnull()]
# Out:
#      Employee_ID Gender  Age  Relationship_Status     Hometown  \
# 7       EID_1235      F  NaN                    1  Springfield
# 15     EID_20121      F  NaN                    1  Springfield
# 25      EID_3901      F  NaN                    1   Washington
# 40     EID_17527      F  NaN                    1  Springfield
# 43      EID_1433      M  NaN                    1  Springfield
# ...          ...    ...  ...                  ...          ...
# 6916   EID_16330      F  NaN                    0     Franklin
# 6945   EID_20301      F  NaN                    0  Springfield
# 6969   EID_18566      F  NaN                    0   Washington
# 6981   EID_25181      M  NaN                    1  Springfield
# 6986   EID_17099      M  NaN                    0     Franklin
#
#                            Unit Decision_skill_possess  Time_of_service  \
# 7                         Sales              Directive             34.0
# ...

# %%
train["Age"]=train["Age"].fillna(train['Age'].median())

# %%
train['Age'].unique()
# Out:
# array([42., 24., 58., 26., 31., 54., 21., 37., 40., 45., 65., 19., 63.,
#        23., 33., 32., 22., 25., 47., 28., 34., 55., 46., 30., 43., 39.,
#        27., 57., 51., 41., 60., 50., 56., 44., 49., 36., 29., 20., 59.,
#        53., 35., 62., 61., 64., 38., 52., 48.])

# %%
train[train["Age"].isnull()]
# Out:
# Empty DataFrame
# Columns: [Employee_ID, Gender, Age, Relationship_Status, Hometown, Unit, Decision_skill_possess, Time_of_service, Time_since_promotion, growth_rate, Travel_Rate, Post_Level, Pay_Scale, Compensation_and_Benefits, Work_Life_balance, Attrition_rate]
# Index: []

# %%
train[train["Time_of_service"].isnull()]
# Out:
#      Employee_ID Gender   Age  Relationship_Status     Hometown        Unit  \
# 27     EID_12981      M  28.0                    0      Lebanon       Sales
# 57     EID_15391      M  24.0                    1  Springfield     Quality
# 96     EID_23317      M  22.0                    1     Franklin  Production
# 104    EID_14719      F  25.0                    1      Lebanon     Quality
# 197     EID_8070      M  40.0                    1  Springfield   Logistics
# ...          ...    ...   ...                  ...          ...         ...
# 6767    EID_4979      F  56.0                    1  Springfield       Sales
# 6809    EID_4479      M  52.0                    1      Lebanon         R&D
# 6843   EID_13050      M  28.0                    1      Lebanon          IT
# 6935    EID_9616      F  46.0                    0   Washington  Operarions
# 6976   EID_15099      M  28.0                    1     Franklin  Operarions
#
# ...

# %%
train["Time_of_service"]=train["Time_of_service"].fillna(train['Time_of_service'].median())

# %%
train[train["Age"].isnull()]
# Out:
# Empty DataFrame
# Columns: [Employee_ID, Gender, Age, Relationship_Status, Hometown, Unit, Decision_skill_possess, Time_of_service, Time_since_promotion, growth_rate, Travel_Rate, Post_Level, Pay_Scale, Compensation_and_Benefits, Work_Life_balance, Attrition_rate]
# Index: []

# %%
train[train["Work_Life_balance"].isnull()]
# Out:
#      Employee_ID Gender   Age  Relationship_Status     Hometown  \
# 728    EID_12062      M  35.0                    0   Washington
# 902    EID_11146      F  37.0                    1      Lebanon
# 1252   EID_20549      M  42.0                    0  Springfield
# 1378   EID_19310      F  21.0                    0     Franklin
# 1634    EID_6814      F  43.0                    0  Springfield
# 2101   EID_25336      M  52.0                    0     Franklin
# 2971    EID_4230      F  64.0                    1  Springfield
# 3954   EID_23012      F  37.0                    0  Springfield
# 4532   EID_19982      F  30.0                    0      Lebanon
# 4735   EID_12687      F  29.0                    1   Washington
# 5010    EID_6341      F  48.0                    1      Lebanon
#
#                         Unit Decision_skill_possess  Time_of_service  \
# 728                Logistics             Behavioral             10.0
# ...

# %%
train["Pay_Scale"]=train["Pay_Scale"].fillna(train["Pay_Scale"].median())

# %%
train["Work_Life_balance"]=train["Work_Life_balance"].fillna(train['Work_Life_balance'].median())

# %%
from sklearn import preprocessing 
  
# label_encoder object knows how to understand word labels. 
label_encoder = preprocessing.LabelEncoder() 
  
# Encode labels in column 'species'. 
train['Hometown']= label_encoder.fit_transform(train['Hometown']) 
  
train['Hometown'].unique()
# Out:
# array([1, 3, 0, 2, 4])

# %%
train
# Out:
#      Employee_ID Gender   Age  Relationship_Status  Hometown  \
# 0      EID_23371      F  42.0                    1         1
# 1      EID_18000      M  24.0                    0         3
# 2       EID_3891      F  58.0                    1         0
# 3      EID_17492      F  26.0                    0         2
# 4      EID_22534      F  31.0                    1         3
# ...          ...    ...   ...                  ...       ...
# 6995   EID_16328      F  23.0                    1         1
# 6996    EID_8387      F  44.0                    1         2
# 6997    EID_8077      F  49.0                    0         3
# 6998   EID_19597      F  47.0                    1         4
# 6999    EID_1640      F  58.0                    1         1
#
#                            Unit Decision_skill_possess  Time_of_service  \
# 0                            IT             Conceptual              4.0
# 1                     Logistics             Analytical              5.0
# ...

# %%
train['Unit_encode']= label_encoder.fit_transform(train['Unit']) 
train['Decision_skill_possess_encode']= label_encoder.fit_transform(train['Decision_skill_possess']) 
train['Compensation_and_Benefits_encode']= label_encoder.fit_transform(train['Compensation_and_Benefits'])

# %%
train["Unit"].unique()
# Out:
# array(['IT', 'Logistics', 'Quality', 'Human Resource Management',
#        'Purchasing', 'Sales', 'Production', 'Operarions',
#        'Accounting and Finance', 'Marketing', 'R&D', 'Security'],
#       dtype=object)

# %%
train
# Out:
#      Employee_ID Gender   Age  Relationship_Status  Hometown  \
# 0      EID_23371      F  42.0                    1         1
# 1      EID_18000      M  24.0                    0         3
# 2       EID_3891      F  58.0                    1         0
# 3      EID_17492      F  26.0                    0         2
# 4      EID_22534      F  31.0                    1         3
# ...          ...    ...   ...                  ...       ...
# 6995   EID_16328      F  23.0                    1         1
# 6996    EID_8387      F  44.0                    1         2
# 6997    EID_8077      F  49.0                    0         3
# 6998   EID_19597      F  47.0                    1         4
# 6999    EID_1640      F  58.0                    1         1
#
#                            Unit Decision_skill_possess  Time_of_service  \
# 0                            IT             Conceptual              4.0
# 1                     Logistics             Analytical              5.0
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7000 entries, 0 to 6999
# Data columns (total 16 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Employee_ID                7000 non-null   object
#  1   Gender                     7000 non-null   object
#  2   Age                        7000 non-null   float64
#  3   Relationship_Status        7000 non-null   int64
#  4   Hometown                   7000 non-null   int32
#  5   Unit                       7000 non-null   int32
#  6   Decision_skill_possess     7000 non-null   int32
#  7   Time_of_service            7000 non-null   float64
#  8   Time_since_promotion       7000 non-null   int64
#  9   growth_rate                7000 non-null   int64
#  10  Travel_Rate                7000 non-null   int64
#  11  Post_Level                 7000 non-null   int64
#  12  Pay_Scale                  7000 non-null   float64
# ...

# %%
train["Gender"]=[1 if i =="M" else 0 for i in train["Gender"]]

# %%
train["Relationship_Status"]=[1 if i =="Married" else 0 for i in train["Relationship_Status"]]

# %%
id=[]
for i in list(train.Employee_ID):
    if not i.isdigit():
        id.append(i.replace("EID_","").strip().split(" ")[0])
train["Employee_ID"]=id

# %%
train["Employee_ID"] = train["Employee_ID"].astype(str).astype(int)
train.dtypes
# Out:
# Employee_ID                    int32
# Gender                         int64
# Age                          float64
# Relationship_Status            int64
# Hometown                       int32
# Unit                           int32
# Decision_skill_possess         int32
# Time_of_service              float64
# Time_since_promotion           int64
# growth_rate                    int64
# Travel_Rate                    int64
# Post_Level                     int64
# Pay_Scale                    float64
# Compensation_and_Benefits      int32
# Work_Life_balance            float64
# Attrition_rate               float64
# dtype: object

# %%
train_len=len(train)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train.columns
# Out:
# Index(['Employee_ID', 'Gender', 'Age', 'Relationship_Status', 'Hometown',
#        'Unit', 'Decision_skill_possess', 'Time_of_service',
#        'Time_since_promotion', 'growth_rate', 'Travel_Rate', 'Post_Level',
#        'Pay_Scale', 'Compensation_and_Benefits', 'Work_Life_balance'],
#       dtype='object')

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5600 entries, 1032 to 860
# Data columns (total 15 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Employee_ID                5600 non-null   int32
#  1   Gender                     5600 non-null   int64
#  2   Age                        5600 non-null   float64
#  3   Relationship_Status        5600 non-null   int64
#  4   Hometown                   5600 non-null   int32
#  5   Unit                       5600 non-null   int32
#  6   Decision_skill_possess     5600 non-null   int32
#  7   Time_of_service            5600 non-null   float64
#  8   Time_since_promotion       5600 non-null   int64
#  9   growth_rate                5600 non-null   int64
#  10  Travel_Rate                5600 non-null   int64
#  11  Post_Level                 5600 non-null   int64
#  12  Pay_Scale                  5600 non-null   float64
# ...

# %%
train_df=train[:train_len]
X_train=train_df.drop(labels=["Attrition_rate"],axis=1)
y_train=train_df["Attrition_rate"]
X_train,X_test ,y_train,y_test=train_test_split(X_train,y_train,test_size=0.2,random_state=42)
print("X_train",len(X_train))
print("X_test",len(X_test))
print("y_train",len(y_train))
print("y_test",len(y_test))
print("test",len(test))

print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# X_train 5600
# X_test 1400
# y_train 5600
# y_test 1400
# test 3000
# (5600, 15) (5600,)
# (1400, 15) (1400,)

# %%
from sklearn.model_selection import train_test_split,StratifiedKFold,GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier, VotingClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7000 entries, 0 to 6999
# Data columns (total 16 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Employee_ID                7000 non-null   int32
#  1   Gender                     7000 non-null   int64
#  2   Age                        7000 non-null   float64
#  3   Relationship_Status        7000 non-null   int64
#  4   Hometown                   7000 non-null   int32
#  5   Unit                       7000 non-null   int32
#  6   Decision_skill_possess     7000 non-null   int32
#  7   Time_of_service            7000 non-null   float64
#  8   Time_since_promotion       7000 non-null   int64
#  9   growth_rate                7000 non-null   int64
#  10  Travel_Rate                7000 non-null   int64
#  11  Post_Level                 7000 non-null   int64
#  12  Pay_Scale                  7000 non-null   float64
# ...

# %%
import numpy as np
train["Hometown"] = np.array(train["Hometown"], dtype=np.int64)
train["Unit"] = np.array(train["Unit"], dtype=np.int64)
train["Employee_ID"] = np.array(train["Employee_ID"], dtype=np.int64)
train["Decision_skill_possess"] = np.array(train["Decision_skill_possess"], dtype=np.int64)
train["Compensation_and_Benefits"] = np.array(train["Compensation_and_Benefits"], dtype=np.int64)

# %%
from sklearn.linear_model import LinearRegression

lr = LinearRegression()
lr.fit(X_train, y_train)
'''LinearRegression()'''
from sklearn.metrics import mean_squared_error
def rmse(y_test,y_pred):
      return np.sqrt(mean_squared_error(y_test,y_pred))

y_pred = lr.predict(X_test)
print("Linear Regressor score on testing set: ", rmse(y_test, y_pred))
# Out:
# Linear Regressor score on testing set:  0.1864695617546958

# %%
Score = 100 * max(0 , 1 - rmse(y_test, y_pred))
print('Accuracy',Score)
# Out:
# Accuracy 81.35304382453042

# %%
import pickle
model_filename = 'lr_model.pkl'

# Save the model to a pickle file
with open(model_filename, 'wb') as model_file:
    pickle.dump(lr, model_file)

# %%
with open(model_filename, 'rb') as model_file:
    loaded_model = pickle.load(model_file)

# %%
def predict_employee_performance(employee_id, gender, age, relationship_status, hometown, unit,
                                 decision_skill_possess, time_of_service, time_since_promotion,
                                 growth_rate, travel_rate, post_level, pay_scale,
                                 compensation_and_benefits, work_life_balance):
    # Preprocess the input
    input_data = np.array([[employee_id, gender, age, relationship_status, hometown, unit,
                            decision_skill_possess, time_of_service, time_since_promotion,
                            growth_rate, travel_rate, post_level, pay_scale,
                            compensation_and_benefits, work_life_balance]])

    # Predict using the model
    predicted_performance = loaded_model.predict(input_data)

    return predicted_performance[0]

# %%
X_train.values[0]
# Out:
# array([2.3173e+04, 1.0000e+00, 1.9000e+01, 0.0000e+00, 1.0000e+00,
#        7.0000e+00, 2.0000e+00, 0.0000e+00, 0.0000e+00, 4.2000e+01,
#        1.0000e+00, 2.0000e+00, 1.0000e+01, 2.0000e+00, 2.0000e+00])

# %%
p1 = predict_employee_performance(2.3173e+04, 1.0000e+00, 1.9000e+01, 0.0000e+00, 1.0000e+00,7.0000e+00, 2.0000e+00, 0.0000e+00, 0.0000e+00, 4.2000e+01,1.0000e+00, 2.0000e+00, 1.0000e+01, 2.0000e+00, 2.0000e+00)
# Out:
# c:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
p1
# Out:
# 0.1834002043029975

# %%
train
# Out:
#       Employee_ID  Gender   Age  Relationship_Status  Hometown  Unit  \
# 0           23371       0  42.0                    0         1     2
# 1           18000       1  24.0                    0         3     3
# 2            3891       0  58.0                    0         0     8
# 3           17492       0  26.0                    0         2     1
# 4           22534       0  31.0                    0         3     3
# ...           ...     ...   ...                  ...       ...   ...
# 6995        16328       0  23.0                    0         1     5
# 6996         8387       0  44.0                    0         2     9
# 6997         8077       0  49.0                    0         3     2
# 6998        19597       0  47.0                    0         4    10
# 6999         1640       0  58.0                    0         1     2
#
#       Decision_skill_possess  Time_of_service  Time_since_promotion  \
# 0                          2              4.0                     4
# ...

# %%
X_train
# Out:
#       Employee_ID  Gender   Age  Relationship_Status  Hometown  Unit  \
# 1032        23173       1  19.0                    0         1     7
# 6339        16281       0  37.0                    0         3     9
# 3886        10259       1  40.0                    0         2     1
# 2653        18112       1  22.0                    0         1     5
# 6914         6050       0  49.0                    0         1     6
# ...           ...     ...   ...                  ...       ...   ...
# 3772        18289       1  22.0                    0         2     6
# 5191         1864       1  64.0                    0         1    10
# 5226        17712       0  25.0                    0         2     2
# 5390        18654       0  21.0                    0         3     5
# 860         24973       0  19.0                    0         3     1
#
#       Decision_skill_possess  Time_of_service  Time_since_promotion  \
# 1032                       2              0.0                     0
# ...
